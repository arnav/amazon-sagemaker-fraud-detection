#  66650K .......... .......... .......... .......... .......... 98%  220M 0s
#  66700K .......... .......... .......... .......... .......... 98%  232M 0s
#  66750K .......... .......... .......... .......... .......... 98%  200M 0s
#  66800K .......... .......... .......... .......... .......... 98%  182M 0s
#  66850K .......... .......... .......... .......... .......... 99% 53.5M 0s
#  66900K .......... .......... .......... .......... .......... 99% 53.8M 0s
#  66950K .......... .......... .......... .......... .......... 99%  223M 0s
#  67000K .......... .......... .......... .......... .......... 99%  242M 0s
#  67050K .......... .......... .......... .......... .......... 99%  269M 0s
#  67100K .......... .......... .......... .......... .......... 99% 66.8M 0s
#  67150K .......... .......... .......... .......... .......... 99%  109M 0s
#  67200K .......... .......... .......... .......... .......... 99%  238M 0s
#  67250K .......... .......... .......... .......... .......... 99%  186M 0s
#  67300K .......... .......... .......... .......... .......... 99%  264M 0s
#  67350K .......... .......... .......... .......... .......... 99%  233M 0s
#  67400K .......... .......... .......... .......... .......... 99%  259M 0s
#  67450K .......... .......... .......... .......... .......... 99%  251M 0s
#  67500K .......... .......... .......... ....                 100%  277M=6.3s
#
# 2020-09-16 11:50:27 (10.5 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]
#
# bash: line 2: unzip: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-e9759d56ad00> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'wget https://s3-us-west-2.amazonaws.com/sagemaker-e2e-solutions/fraud-detection/creditcardfraud.zip\nunzip creditcardfraud.zip\n')
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# -> 2362                 result = fn(*args, **kwargs)
#    2363             return result
#    2364
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# </opt/conda/lib/python3.7/site-packages/decorator.py:decorator-gen-110> in shebang(self, line, cell)
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'wget https://s3-us-west-2.amazonaws.com/sagemaker-e2e-solutions/fraud-detection/creditcardfraud.zip\nunzip creditcardfraud.zip\n'' returned non-zero exit status 127.

# %%
# !conda install -y -c conda-forge unzip
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - unzip
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.5                |   py37hc8dfbb8_1         3.0 MB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     unzip-6.0                  |       h516909a_2         141 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/linux-64::python_abi-3.7-1_cp37m
#   unzip              conda-forge/linux-64::unzip-6.0-h516909a_2
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.2-py37_0 --> conda-forge::conda-4.8.5-py37hc8dfbb8_1
#
#
#
# Downloading and Extracting Packages
# conda-4.8.5          | 3.0 MB    | ##################################### | 100%
# python_abi-3.7       | 4 KB      | ##################################### | 100%
# unzip-6.0            | 141 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !unzip creditcardfraud.zip
# Out:
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('creditcard.csv', delimiter=',')

# %% [markdown]
# Let's take a peek at our data (we only show a subset of the columns in the table):

# %%
print(data.columns)
data[['Time', 'V1', 'V2', 'V27', 'V28', 'Amount', 'Class']].describe()
data.head(10)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %% [markdown]
# The class column corresponds to whether or not a transaction is fradulent. We see that the majority of data is non-fraudulant with only $492$ ($.173\%$) of the data corresponding to fraudulant examples.

# %%
nonfrauds, frauds = data.groupby('Class').size()
print('Number of frauds: ', frauds)
print('Number of non-frauds: ', nonfrauds)
print('Percentage of fradulent data:', 100.*frauds/(frauds + nonfrauds))
# Out:
# Number of frauds:  492
# Number of non-frauds:  284315
# Percentage of fradulent data: 0.1727485630620034

# %% [markdown]
# This dataset has 28 columns, $V_i$ for $i=1..28$ of anonymized features along with columns for time, amount, and class. We already know that the columns $V_i$ have been normalized to have $0$ mean and unit standard deviation as the result of a PCA. You can read more about PCA here:.
#
# Tip: For our dataset this amount of preprocessing will give us reasonable accuracy, but it's important to note that there are more preprocessing steps one can use to improve accuracy . For unbalanced data sets like ours where the positive (fraudulent) examples occur much less frequently than the negative (legitimate) examples, we may try “over-sampling” the minority dataset by generating synthetic data (read about SMOTE in Data Mining for Imbalanced Datasets: An Overview (https://link.springer.com/chapter/10.1007%2F0-387-25465-X_40) or undersampling the majority class by using ensemble methods (see http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.68.6858&rep=rep1&type=pdfor).

# %%
feature_columns = data.columns[:-1]
label_column = data.columns[-1]

features = data[feature_columns].values.astype('float32')
labels = (data[label_column].values).astype('float32')

# %% [markdown]
# Let's do some analysis and discuss different ways we can preprocess our data. Let's discuss the way in which this data was preprocessed.

# %% [markdown]
# ## SageMaker XGB

# %% [markdown]
# ### Prepare Data and Upload to S3

# %% [markdown]
# The Amazon common libraries provide utilities to convert NumPy n-dimensional arrays into a the Record-IO format which SageMaker uses for a concise representation of features and labels. The Record-IO format is implemented via protocol buffer so the serialization is very efficient.

# %%
model_data = data
model_data.head()
model_data = pd.concat([model_data['Class'], model_data.drop(['Class'], axis=1)], axis=1)
model_data.head()
# Out:
#    Class  Time        V1        V2        V3        V4        V5        V6  \
# 0      0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      0   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2      0   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3      0   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4      0   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8  ...       V20       V21       V22       V23       V24  \
# 0  0.239599  0.098698  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1  0.167170  0.125895 -0.008983  0.014724    2.69
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3  0.647376 -0.221929  0.062723  0.061458  123.50
# 4 -0.206010  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Now we upload the data to S3 using boto3.

# %%
import boto3
import os
import sagemaker

session = sagemaker.Session()

bucket = session.default_bucket()
sagemaker_iam_role = sagemaker.get_execution_role()

prefix = 'sagemaker/DEMO-xgboost-fraud'

train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), 
                                                  [int(0.7 * len(model_data)), int(0.9 * len(model_data))])
train_data.to_csv('train.csv', header=False, index=False)
validation_data.to_csv('validation.csv', header=False, index=False)


boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')) \
                                .upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')) \
                                .upload_file('validation.csv')
s3_train_data = 's3://{}/{}/train/train.csv'.format(bucket, prefix)
s3_validation_data = 's3://{}/{}/validation/validation.csv'.format(bucket, prefix)
print('Uploaded training data location: {}'.format(s3_train_data))
print('Uploaded training data location: {}'.format(s3_validation_data))

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('Training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# Uploaded training data location: s3://sagemaker-eu-west-1-736760139033/sagemaker/DEMO-xgboost-fraud/train/train.csv
# Uploaded training data location: s3://sagemaker-eu-west-1-736760139033/sagemaker/DEMO-xgboost-fraud/validation/validation.csv
# Training artifacts will be uploaded to: s3://sagemaker-eu-west-1-736760139033/sagemaker/DEMO-xgboost-fraud/output

# %% [markdown]
# ---
# ## Train
#
# Moving onto training, first we'll need to specify the locations of the XGBoost algorithm containers.
# To specify the Linear Learner algorithm, we use a utility function to obtain it's URI. A complete list of build-in algorithms is found here: https://docs.aws.amazon.com/sagemaker/latest/dg/algos.html

# %%
import sagemaker.image_uris
container = sagemaker.image_uris.retrieve('xgboost', boto3.Session().region_name, version='latest', image_scope='training')

# %% [markdown]
# Then, because we're training with the CSV file format, we'll create s3_inputs that our training function can use as a pointer to the files in S3.

# %%
s3_input_train = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

# %% [markdown]
# Now, we can specify a few parameters like what type of training instances we'd like to use and how many, as well as our XGBoost hyperparameters.  A few key hyperparameters are:
# - `max_depth` controls how deep each tree within the algorithm can be built.  Deeper trees can lead to better fit, but are more computationally expensive and can lead to overfitting.  There is typically some trade-off in model performance that needs to be explored between a large number of shallow trees and a smaller number of deeper trees.
# - `subsample` controls sampling of the training data.  This technique can help reduce overfitting, but setting it too low can also starve the model of data.
# - `num_round` controls the number of boosting rounds.  This is essentially the subsequent models that are trained using the residuals of previous iterations.  Again, more rounds should produce a better fit on the training data, but can be computationally expensive or lead to overfitting.
# - `eta` controls how aggressive each round of boosting is.  Larger values lead to more conservative boosting.
# - `gamma` controls how aggressively trees are grown.  Larger values lead to more conservative models.
#
# More detail on XGBoost's hyperparmeters can be found on their GitHub [page](https://github.com/dmlc/xgboost/blob/master/doc/parameter.md).

# %% [markdown]
# SageMaker abstracts training with Estimators. We can pass container, and all parameters to the estimator, as well as the hyperparameters for the linear learner and fit the estimator to the data in S3.
# Note: For IP protection reasons, SageMaker built-in algorithms, such as XGBoost, can't be run locally, i.e. on the same instance where this Jupyter Notebook code is running.

# %%
xgb = sagemaker.estimator.Estimator(container,
                                    role=sagemaker_iam_role, 
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge',
                                    output_path=output_location,
                                    sagemaker_session=session)


xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        num_round=100)

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-09-16 12:07:59 Starting - Starting the training job...
# 2020-09-16 12:08:01 Starting - Launching requested ML instances......
# 2020-09-16 12:09:28 Starting - Preparing the instances for training......
# 2020-09-16 12:10:21 Downloading - Downloading input data...
# 2020-09-16 12:10:56 Training - Training image download completed. Training in progress..Arguments: train
# [2020-09-16:12:10:56:INFO] Running standalone xgboost training.
# [2020-09-16:12:10:56:INFO] File size need to be processed in the node: 133.78mb. Available memory size in the node: 8500.76mb
# [2020-09-16:12:10:56:INFO] Determined delimiter of CSV input is ','
# [12:10:56] S3DistributionType set as FullyReplicated
# [12:10:57] 199364x30 matrix with 5980920 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-09-16:12:10:57:INFO] Determined delimiter of CSV input is ','
# [12:10:57] S3DistributionType set as FullyReplicated
# [12:10:57] 56962x30 matrix with 1708860 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [12:10:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-error:0.000647#011validation-error:0.000632
# [12:10:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=4
# [1]#011train-error:0.000517#011validation-error:0.000509
# [12:10:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=4
# [2]#011train-error:0.000466#011validation-error:0.000544
# [12:10:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=4
# [3]#011train-error:0.000461#011validation-error:0.000509
# [12:10:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [4]#011train-error:0.000456#011validation-error:0.000527
# [12:10:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=4
# [5]#011train-error:0.000446#011validation-error:0.000492
# [12:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [6]#011train-error:0.000431#011validation-error:0.000492
# [12:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [7]#011train-error:0.000431#011validation-error:0.000492
# [12:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=3
# [8]#011train-error:0.000421#011validation-error:0.000492
# [12:11:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=4
# [9]#011train-error:0.000421#011validation-error:0.000474
# [12:11:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=3
# [10]#011train-error:0.000431#011validation-error:0.000474
# [12:11:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [11]#011train-error:0.000416#011validation-error:0.000474
# [12:11:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [12]#011train-error:0.000426#011validation-error:0.000492
# [12:11:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=3
# [13]#011train-error:0.000426#011validation-error:0.000492
# [12:11:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [14]#011train-error:0.000426#011validation-error:0.000492
# [12:11:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [15]#011train-error:0.000416#011validation-error:0.000474
# [12:11:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 16 pruned nodes, max_depth=3
# [16]#011train-error:0.000426#011validation-error:0.000527
# [12:11:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=3
# [17]#011train-error:0.000416#011validation-error:0.000527
# [12:11:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [18]#011train-error:0.000421#011validation-error:0.000527
# [12:11:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=4
# [19]#011train-error:0.000416#011validation-error:0.000527
# [12:11:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [20]#011train-error:0.000416#011validation-error:0.000544
# [12:11:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=4
# [21]#011train-error:0.000396#011validation-error:0.000492
# [12:11:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [22]#011train-error:0.000401#011validation-error:0.000509
# [12:11:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [23]#011train-error:0.000401#011validation-error:0.000492
# [12:11:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=3
# [24]#011train-error:0.000401#011validation-error:0.000492
# [12:11:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=3
# [25]#011train-error:0.000401#011validation-error:0.000509
# [12:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [26]#011train-error:0.000396#011validation-error:0.000456
# [12:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [27]#011train-error:0.000371#011validation-error:0.000492
# [12:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=4
# [28]#011train-error:0.000371#011validation-error:0.000509
# [12:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [29]#011train-error:0.000376#011validation-error:0.000509
# [12:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [30]#011train-error:0.000371#011validation-error:0.000474
# [12:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=4
# [31]#011train-error:0.000361#011validation-error:0.000492
# [12:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [32]#011train-error:0.000361#011validation-error:0.000509
# [12:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=4
# [33]#011train-error:0.000356#011validation-error:0.000492
# [12:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=4
# [34]#011train-error:0.000356#011validation-error:0.000509
# [12:11:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=2
# [35]#011train-error:0.000356#011validation-error:0.000509
# [12:11:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [36]#011train-error:0.000351#011validation-error:0.000527
# [12:11:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [37]#011train-error:0.000351#011validation-error:0.000509
# [12:11:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=4
# [38]#011train-error:0.000346#011validation-error:0.000509
# [12:11:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [39]#011train-error:0.000341#011validation-error:0.000544
# [12:11:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=3
# [40]#011train-error:0.000351#011validation-error:0.000544
# [12:11:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [41]#011train-error:0.000351#011validation-error:0.000544
# [12:11:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [42]#011train-error:0.000356#011validation-error:0.000544
# [12:11:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [43]#011train-error:0.000351#011validation-error:0.000544
# [12:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [44]#011train-error:0.000331#011validation-error:0.000544
# [12:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [45]#011train-error:0.000326#011validation-error:0.000544
# [12:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=4
# [46]#011train-error:0.000311#011validation-error:0.000544
# [12:11:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [47]#011train-error:0.000316#011validation-error:0.000544
# [12:11:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [48]#011train-error:0.000331#011validation-error:0.000544
# [12:11:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [49]#011train-error:0.000326#011validation-error:0.000544
# [12:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=4
# [50]#011train-error:0.000326#011validation-error:0.000509
# [12:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [51]#011train-error:0.000321#011validation-error:0.000509
# [12:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 8 pruned nodes, max_depth=4
# [52]#011train-error:0.000316#011validation-error:0.000527
# [12:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=4
# [53]#011train-error:0.000311#011validation-error:0.000527
# [12:11:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [54]#011train-error:0.000311#011validation-error:0.000527
# [12:11:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [55]#011train-error:0.000301#011validation-error:0.000509
# [12:11:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [56]#011train-error:0.000301#011validation-error:0.000509
# [12:11:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [57]#011train-error:0.000311#011validation-error:0.000492
# [12:11:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [58]#011train-error:0.000306#011validation-error:0.000509
# [12:11:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [59]#011train-error:0.000311#011validation-error:0.000492
# [12:11:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=3
# [60]#011train-error:0.000311#011validation-error:0.000492
# [12:11:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=3
# [61]#011train-error:0.000296#011validation-error:0.000492
# [12:11:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [62]#011train-error:0.000311#011validation-error:0.000492
# [12:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [63]#011train-error:0.000301#011validation-error:0.000492
# [12:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=4
# [64]#011train-error:0.000276#011validation-error:0.000492
# [12:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [65]#011train-error:0.000286#011validation-error:0.000492
# [12:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [66]#011train-error:0.000286#011validation-error:0.000492
# [12:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=2
# [67]#011train-error:0.000291#011validation-error:0.000474
# [12:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [68]#011train-error:0.000286#011validation-error:0.000474
# [12:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [69]#011train-error:0.000286#011validation-error:0.000474
# [12:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [70]#011train-error:0.000286#011validation-error:0.000492
# [12:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [71]#011train-error:0.000286#011validation-error:0.000474
# [12:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [72]#011train-error:0.000286#011validation-error:0.000492
# [12:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [73]#011train-error:0.000281#011validation-error:0.000492
# [12:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=4
# [74]#011train-error:0.000271#011validation-error:0.000492
# [12:11:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [75]#011train-error:0.000271#011validation-error:0.000492
# [12:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [76]#011train-error:0.000276#011validation-error:0.000492
# [12:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [77]#011train-error:0.000271#011validation-error:0.000492
# [12:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 10 pruned nodes, max_depth=2
# [78]#011train-error:0.000271#011validation-error:0.000492
# [12:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [79]#011train-error:0.000271#011validation-error:0.000474
# [12:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [80]#011train-error:0.000266#011validation-error:0.000474
# [12:11:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=4
# [81]#011train-error:0.000271#011validation-error:0.000474
# [12:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [82]#011train-error:0.000271#011validation-error:0.000474
# [12:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [83]#011train-error:0.000271#011validation-error:0.000474
# [12:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [84]#011train-error:0.000271#011validation-error:0.000474
# [12:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [85]#011train-error:0.000271#011validation-error:0.000474
# [12:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [86]#011train-error:0.000271#011validation-error:0.000492
# [12:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [87]#011train-error:0.000271#011validation-error:0.000474
# [12:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [88]#011train-error:0.000271#011validation-error:0.000474
# [12:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [89]#011train-error:0.000271#011validation-error:0.000474
# [12:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=4
# [90]#011train-error:0.000271#011validation-error:0.000474
# [12:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [91]#011train-error:0.000266#011validation-error:0.000474
# [12:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [92]#011train-error:0.000266#011validation-error:0.000474
# [12:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [93]#011train-error:0.000271#011validation-error:0.000474
# [12:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [94]#011train-error:0.000271#011validation-error:0.000456
# [12:11:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [95]#011train-error:0.000266#011validation-error:0.000456
# [12:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [96]#011train-error:0.000256#011validation-error:0.000456
# [12:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 4 pruned nodes, max_depth=3
# [97]#011train-error:0.000266#011validation-error:0.000456
# [12:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [98]#011train-error:0.000261#011validation-error:0.000456
# [12:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [99]#011train-error:0.000261#011validation-error:0.000456
#
# 2020-09-16 12:11:39 Uploading - Uploading generated training model
# 2020-09-16 12:11:39 Completed - Training job completed
# Training seconds: 78
# Billable seconds: 78

# %% [markdown]
# ### Host XGBoost Model

# %% [markdown]
# Now we deploy the estimator to and endpoint.

# %%
xgb.name = 'deployed-xgboost-fraud-prediction'
xgb_predictor = xgb.deploy(initial_instance_count = 1, instance_type = 'ml.m4.xlarge',
                          endpoint_name='deployed-xgboost-fraud-prediction')
# Out:
# -------------!

# %% [markdown]
# ### Evaluate
#
# Now that we have a hosted endpoint running, we can make real-time predictions from our model very easily,
# simply by making an http POST request.  But first, we'll need to setup serializers and deserializers for passing our `test_data` NumPy arrays to the model behind the endpoint.

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import CSVDeserializer

csv_serializer = CSVSerializer()
csv_deserializer = CSVDeserializer()

xgb_predictor.serializer = csv_serializer
xgb_predictor.deserializer = csv_deserializer

# %% [markdown]
# Now, we'll use a simple function to:
# 1. Loop over our test dataset
# 1. Split it into mini-batches of rows
# 1. Convert those mini-batchs to CSV string payloads
# 1. Retrieve mini-batch predictions by invoking the XGBoost endpoint
# 1. Collect predictions and convert from the CSV output our model provides into a NumPy array

# %%
def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        results = xgb_predictor.predict(data=array)
        predictions += ',' + ','.join(results[0])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(test_data.to_numpy()[:, 1:])

# %% [markdown]
# There are many ways to compare the performance of a machine learning model, but let's start by simply by comparing actual to predicted values. In this case, we're simply predicting whether the customer churned (1) or not (0), which produces a simple confusion matrix.

# %%
test_nonfrauds, test_frauds = test_data.groupby('Class').size()
print('Number of frauds: ', test_frauds)
print('Number of non-frauds: ', test_nonfrauds)
print('Percentage of fradulent data:', 100.*test_frauds/(test_frauds + test_nonfrauds))
# Out:
# Number of frauds:  54
# Number of non-frauds:  28427
# Percentage of fradulent data: 0.1896000842667041

# %%
pd.crosstab(index=test_data.iloc[:, 0], columns=np.round(predictions), rownames=['actual'], colnames=['predictions'])
# Out:
# predictions    0.0  1.0
# actual
# 0            28426    1
# 1               14   40

# %%
#precision: tp / (tp + fp)
#recall: tp / (tp + fn)
from sklearn.metrics import precision_recall_fscore_support
results = precision_recall_fscore_support(test_data.iloc[:, 0],
                                         np.round(predictions))
print('precision: ', round(results[0][1], 2))
print('recall: ', round(results[1][1], 2))
# Out:
# precision:  0.98
# recall:  0.74

# %% [markdown]
# Note, due to randomized elements of the algorithm, you results may differ slightly.
#
# Of the 54 fraudsters, we've correctly predicted 40 of them (true positives). And, we incorrectly predicted 1 case of fraud (false positive). There are also 14 cases of fraud that the model classified as benign transaction (false negatives) - which can get really expensive.
#
# An important point here is that because of the np.round() function above we are using a simple threshold (or cutoff) of 0.5. Our predictions from xgboost come out as continuous values between 0 and 1 and we force them into the binary classes that we began with. So, we should consider adjusting this cutoff. That will almost certainly increase the number of false positives, but it can also be expected to increase the number of true positives and reduce the number of false negatives.
#
# To get a rough intuition here, let's look at the continuous values of our predictions.

# %%
plt.hist(predictions)
plt.show()

# %% [markdown]
# By varying the cutoff threshold, we can trade false positives for false negatives.

# %%
pd.crosstab(index=test_data.iloc[:, 0], columns=np.where(predictions > 0.04, 1, 0))
# Out:
# col_0      0   1
# Class
# 0      28411  16
# 1          7  47

# %%
results = precision_recall_fscore_support(test_data.iloc[:, 0],
                                         np.where(predictions > 0.04, 1, 0))
print('precision: ', round(results[0][1], 2))
print('recall: ', round(results[1][1], 2))
# Out:
# precision:  0.75
# recall:  0.87

# %%
plt.hist(predictions)
plt.show()

# %% [markdown]
# ### Relative cost of errors
#
# Any practical binary classification problem is likely to produce a similarly sensitive cutoff.
# If we put an ML model into production, there are costs associated with the model erroneously assigning false positives and false negatives. Because the choice of the cutoff affects all four of these statistics, we need to consider the relative costs to the business for each of these four outcomes for each prediction.
#
# #### Assigning costs
#
# What are the costs for our problem fraud detection? The costs, of course, depend on the specific actions that the business takes. Let's make some assumptions here.
#
# First, assign the cost of \$0.00 to both the true negatives (correctly recognized benign transactions) and true positives (correctly recognized fraudulent transactions). Our model essentially correctly identified both situations. One can assign a benefit (i.e. negative cost) to correctly detected fraud, but we are not going to do this here.
#
# False negatives are the most problematic, because they represent a fraudulent transactions that slipped through our model. Based on some Internet research (see sources below), we assign a cost of \$450.00 for each one. This is the cost of false negatives.
#
# Finally, False positives are the genuine transactions that our model would block as fraud. This would result in an annoyed customer that might possibly close the credit card account and move to another bank. We assume that it costs a \$500.00 sign-on bonus to obtain a cr. card customer and that \5 percent of annoyed customers would defect.
#
# Source:
#
# https://www.creditcards.com/credit-card-news/credit-card-security-id-theft-fraud-statistics-1276.php
# https://wallethub.com/edu/cc/credit-debit-card-fraud-statistics/25725/

# %% [markdown]
# #### Finding the optimal cutoff
#
# It’s clear that false negatives are substantially more costly than false positives. We should be minimizing a cost function that looks like this:
#
# ```txt
# $450 * FN(C) + $0 * TN(C) + 0.05*$500 * FP(C) + $0 * TP(C)
# ```
#
# FN(C) means that the false negative percentage is a function of the cutoff, C, and similar for TN, FP, and TP.  We need to find the cutoff, C, where the result of the expression is smallest.
#
# A straightforward way to do this, is to simply run a simulation over a large number of possible cutoffs.  We test 100 possible values in the for loop below.

# %%
TN_cost = 0
TP_cost = 0
FP_cost = 0.05*500 #$cost of losing an annoyed customer (assuming 5% defection and $500 sign-on bonus)
FN_cost = 450 # $cost of of letting a fradulent transaction slip through

cutoffs = np.arange(0.01, 1, 0.01)
costs = []
for c in cutoffs:
    costs.append(np.sum(np.sum(np.array([[TN_cost, FP_cost], [FN_cost, TP_cost]]) * 
                               pd.crosstab(index=test_data.iloc[:, 0], 
                                           columns=np.where(predictions > c, 1, 0)))))

costs = np.array(costs)
plt.plot(cutoffs, costs)
plt.show()
print('Cost is minimized near a cutoff of:', cutoffs[np.argmin(costs)])
# Out:
# Cost is minimized near a cutoff of: 0.04

# %% [markdown]
# ## Clean up
#
# We will leave the prediction endpoint running at the end of this notebook so we can handle incoming event streams. However, don't forget to delete the prediction endpoint when you're done. You can do that at the Amazon SageMaker console in the Endpoints page. Or you can run `xgb_predictor.delete_endpoint()`

# %%
#xgb_predictor.delete_endpoint()

# %% [markdown]
# ## Data Acknowledgements
#
# The dataset used to demonstrated the fraud detection solution has been collected and analysed during a research collaboration of Worldline and the Machine Learning Group (http://mlg.ulb.ac.be) of ULB (Université Libre de Bruxelles) on big data mining and fraud detection. More details on current and past projects on related topics are available on https://www.researchgate.net/project/Fraud-detection-5 and the page of the [DefeatFraud](https://mlg.ulb.ac.be/wordpress/portfolio_page/defeatfraud-assessment-and-validation-of-deep-feature-engineering-and-learning-solutions-for-fraud-detection/) project
# We cite the following works:
# * Andrea Dal Pozzolo, Olivier Caelen, Reid A. Johnson and Gianluca Bontempi. Calibrating Probability with Undersampling for Unbalanced Classification. In Symposium on Computational Intelligence and Data Mining (CIDM), IEEE, 2015
# * Dal Pozzolo, Andrea; Caelen, Olivier; Le Borgne, Yann-Ael; Waterschoot, Serge; Bontempi, Gianluca. Learned lessons in credit card fraud detection from a practitioner perspective, Expert systems with applications,41,10,4915-4928,2014, Pergamon
# * Dal Pozzolo, Andrea; Boracchi, Giacomo; Caelen, Olivier; Alippi, Cesare; Bontempi, Gianluca. Credit card fraud detection: a realistic modeling and a novel learning strategy, IEEE transactions on neural networks and learning systems,29,8,3784-3797,2018,IEEE
# * Dal Pozzolo, Andrea Adaptive Machine learning for credit card fraud detection ULB MLG PhD thesis (supervised by G. Bontempi)
# * Carcillo, Fabrizio; Dal Pozzolo, Andrea; Le Borgne, Yann-Aël; Caelen, Olivier; Mazzer, Yannis; Bontempi, Gianluca. Scarff: a scalable framework for streaming credit card fraud detection with Spark, Information fusion,41, 182-194,2018,Elsevier
# * Carcillo, Fabrizio; Le Borgne, Yann-Aël; Caelen, Olivier; Bontempi, Gianluca. Streaming active learning strategies for real-life credit card fraud detection: assessment and visualization, International Journal of Data Science and Analytics, 5,4,285-300,2018,Springer International Publishing
